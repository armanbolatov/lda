# %% [markdown]
# # Fashion-MNIST Classification with a Softmax Head
# This notebook mirrors the LDA-based workflow, but uses a standard softmax classifier head on top of the encoder.

# %% [markdown]
# ### Setup

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device =', device)
# Out:
# device = cuda

# %% [markdown]
# ### Data

# %%
tfm = transforms.ToTensor()
train_ds = datasets.FashionMNIST(root='./data', train=True, transform=tfm, download=True)
test_ds  = datasets.FashionMNIST(root='./data', train=False, transform=tfm, download=True)
train_ld = DataLoader(train_ds, batch_size=256, shuffle=True, num_workers=2, pin_memory=True)
test_ld  = DataLoader(test_ds,  batch_size=1024, shuffle=False, num_workers=2, pin_memory=True)
len(train_ds), len(test_ds)
# Out:
# (60000, 10000)

# %% [markdown]
# ### Model: encoder + softmax head

# %%
class Encoder(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.Linear(28 * 28, 256), nn.ReLU(inplace=True),
            nn.Linear(256, 64), nn.ReLU(inplace=True),
            nn.Linear(64, dim),
        )

    def forward(self, x):
        return self.net(x)

class SoftmaxHead(nn.Module):
    def __init__(self, D, C):
        super().__init__()
        self.linear = nn.Linear(D, C)

    def forward(self, z):
        return self.linear(z)

class DeepClassifier(nn.Module):
    def __init__(self, C, D):
        super().__init__()
        self.encoder = Encoder(D)
        self.head = SoftmaxHead(D, C)

    def forward(self, x):
        z = self.encoder(x)
        return self.head(z)

# %% [markdown]
# ### Train & Eval

# %%
@torch.no_grad()
def evaluate(model, loader):
    model.eval()
    ok = tot = 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        ok += (logits.argmax(1) == y).sum().item()
        tot += y.size(0)
    return ok / tot

model = DeepClassifier(C=10, D=2).to(device)
opt = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn = nn.CrossEntropyLoss()

for epoch in range(1, 21):
    model.train()
    loss_sum = acc_sum = n_sum = 0
    for x, y in train_ld:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        loss = loss_fn(logits, y)

        opt.zero_grad(set_to_none=True)
        loss.backward()
        opt.step()

        with torch.no_grad():
            pred = logits.argmax(1)
            acc_sum += (pred == y).sum().item()
            n_sum += y.size(0)
            loss_sum += loss.item() * y.size(0)

    tr_acc = acc_sum / n_sum
    te_acc = evaluate(model, test_ld)
    print(f"[{epoch:02d}] train loss={loss_sum/n_sum:.4f} acc={tr_acc:.4f} | test acc={te_acc:.4f}")
# Out:
# [01] train loss=1.3268 acc=0.5153 | test acc=0.6609
# [02] train loss=0.7672 acc=0.7471 | test acc=0.7752
# [03] train loss=0.6310 acc=0.7955 | test acc=0.7974
# [04] train loss=0.5733 acc=0.8096 | test acc=0.7907
# [05] train loss=0.5302 acc=0.8256 | test acc=0.8223
# [06] train loss=0.4975 acc=0.8379 | test acc=0.8246
# [07] train loss=0.4729 acc=0.8465 | test acc=0.8342
# [08] train loss=0.4493 acc=0.8549 | test acc=0.8407
# [09] train loss=0.4298 acc=0.8605 | test acc=0.8457
# [10] train loss=0.4116 acc=0.8665 | test acc=0.8462
# [11] train loss=0.3937 acc=0.8733 | test acc=0.8512
# [12] train loss=0.3825 acc=0.8757 | test acc=0.8511
# [13] train loss=0.3695 acc=0.8804 | test acc=0.8427
# [14] train loss=0.3582 acc=0.8833 | test acc=0.8502
# [15] train loss=0.3419 acc=0.8877 | test acc=0.8549
# [16] train loss=0.3315 acc=0.8904 | test acc=0.8598
# [17] train loss=0.3235 acc=0.8935 | test acc=0.8599
# [18] train loss=0.3117 acc=0.8963 | test acc=0.8581
# [19] train loss=0.3070 acc=0.8979 | test acc=0.8593
# [20] train loss=0.2998 acc=0.8997 | test acc=0.8595

# %%
import matplotlib.pyplot as plt
import numpy as np

model.eval()
# Out:
# DeepClassifier(
#   (encoder): Encoder(
#     (net): Sequential(
#       (0): Flatten(start_dim=1, end_dim=-1)
#       (1): Linear(in_features=784, out_features=256, bias=True)
#       (2): ReLU(inplace=True)
#       (3): Linear(in_features=256, out_features=64, bias=True)
#       (4): ReLU(inplace=True)
#       (5): Linear(in_features=64, out_features=2, bias=True)
#     )
#   )
#   (head): SoftmaxHead(
#     (linear): Linear(in_features=2, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ### Collect a Small Random Subset of Embeddings

# %%
emb_list, y_list = [], []
max_points = int(len(train_ld.dataset) * 0.05)

with torch.no_grad():
    for X, y in train_ld:
        X, y = X.to(device), y.to(device)
        z = model.encoder(X)
        emb_list.append(z)
        y_list.append(y)
        if sum(t.shape[0] for t in emb_list) >= max_points:
            break

Z = torch.cat(emb_list, dim=0).cpu().numpy()[:max_points]
Y = torch.cat(y_list, dim=0).cpu().numpy()[:max_points]
Z.shape, Y.shape
# Out:
# ((3000, 2), (3000,))

# %% [markdown]
# ### Inspect Learned Classifier Weights

# %%
W = model.head.linear.weight.detach().cpu()
b = model.head.linear.bias.detach().cpu()
W.shape, b.shape
# Out:
# (torch.Size([10, 2]), torch.Size([10]))

# %% [markdown]
# ### Visualise Embeddings

# %%
plt.figure(figsize=(7, 6))
cmap = plt.get_cmap("tab10", 10)
markers = ['o','s','^','v','<','>','P','X','D','*']

for c in range(10):
    idx = (Y == c)
    plt.scatter(Z[idx, 0], Z[idx, 1], s=8, alpha=0.6,
                c=[cmap(c)], marker=markers[c], label=f"{c}")

plt.title("Deep softmax head on Fashion-MNIST: sampled training embeddings")
plt.xlabel("Embedding dim 1")
plt.ylabel("Embedding dim 2")
plt.legend(fontsize=8, ncol=2, frameon=False)
plt.tight_layout()
plt.show()
